# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (8,5)

# %%
df = pd.read_csv('data\sharma-kohli.csv')

# %%
df
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(df['index'], df['V Kohli'])
plt.plot(df['index'], df['RG Sharma'])
plt.title('Rohit vs Virat')
plt.xlabel('Runs')
plt.ylabel('Year')
# Out:
# Text(0, 0.5, 'Year')

# %%
# legend -> location
plt.plot(df['index'],df['V Kohli'],label='Virat')
plt.plot(df['index'],df['RG Sharma'],label='Rohit')

plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')

plt.legend(loc='best')

# %%
df = pd.read_csv(r'C:\Users\hkdtu\Desktop\Practice\data\batter.csv')
df.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
# legend -> location
plt.scatter(df['runs'],df['avg'])

plt.title('IPL Runs vs Avg')
plt.xlabel('Runs')
plt.ylabel('Average')

plt.legend(loc='best')

# %%
df = pd.read_csv(r'C:\Users\hkdtu\Desktop\Practice\data\Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['Species'] = df['Species'].replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

# %%
df.sample(4)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 87    88            6.3           2.3            4.4           1.3        1
# 129  130            7.2           3.0            5.8           1.6        2
# 50    51            7.0           3.2            4.7           1.4        1
# 118  119            7.7           2.6            6.9           2.3        2

# %%
plt.scatter(df['PetalLengthCm'], df['SepalLengthCm'], c=df['Species'], cmap='winter')

plt.xlabel('Petal length')
plt.ylabel('Sepal length')
plt.colorbar()

# %%
df['Id'].values[2]
# Out:
# np.int64(3)

# %% [markdown]
# | High-level Task | Function  | `kind` options                                    |
# | --------------- | --------- | ------------------------------------------------- |
# | Relationship    | `relplot` | `scatter`, `line`                                 |
# | Distribution    | `displot` | `hist`, `kde`, `ecdf`                             |
# | Categorical     | `catplot` | `strip`, `swarm`, `box`, `violin`, `bar`, `count` |
